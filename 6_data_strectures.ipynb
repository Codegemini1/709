# %%
l = [1,2,3,2,1,3]

# %%
l
# Out:
# [1, 2, 3, 2, 1, 3]

# %%
l.append(10)

# %%
l
# Out:
# [1, 2, 3, 2, 1, 3, 10]

# %%
l.append('Hello')

# %%
l
# Out:
# [1, 2, 3, 2, 1, 3, 10, 'Hello']

# %%
l.append([10,20,30])

# %%
l
# Out:
# [1, 2, 3, 2, 1, 3, 10, 'Hello', [10, 20, 30]]

# %%
l.extend([10,20,30])

# %%
l
# Out:
# [1, 2, 3, 2, 1, 3, 10, 'Hello', [10, 20, 30], 10, 20, 30]

# %%
l.extend('hello')

# %%
l
# Out:
# [1,
#  2,
#  3,
#  2,
#  1,
#  3,
#  10,
#  'Hello',
#  [10, 20, 30],
#  10,
#  20,
#  30,
#  'h',
#  'e',
#  'l',
#  'l',
#  'o']

# %%
names = ['Om', 'priya', 'payal', 'sham']

# %%
names
# Out:
# ['Om', 'priya', 'payal', 'sham']

# %%
names.append('Vaibhav')

# %%
names
# Out:
# ['Om', 'priya', 'payal', 'sham', 'Vaibhav']

# %%
names.extend('onkar')

# %%
names
# Out:
# ['Om', 'priya', 'payal', 'sham', 'Vaibhav', 'o', 'n', 'k', 'a', 'r']

# %%
l
# Out:
# [1,
#  2,
#  3,
#  2,
#  1,
#  3,
#  10,
#  'Hello',
#  [10, 20, 30],
#  10,
#  20,
#  30,
#  'h',
#  'e',
#  'l',
#  'l',
#  'o']

# %%
l2 = [1,1,1,1,2,2,2,2,3,4,5,6,7,8]

# %%
l2
# Out:
# [1, 1, 1, 1, 2, 2, 2, 2, 3, 4, 5, 6, 7, 8]

# %%
names
# Out:
# ['Om', 'priya', 'payal', 'sham', 'Vaibhav', 'o', 'n', 'k', 'a', 'r']

# %%
# names[1] = 'Ganesh'

# %%
names.insert(1,'Ganesh')

# %%
names
# Out:
# ['Om', 'Ganesh', 'priya', 'payal', 'sham', 'Vaibhav', 'o', 'n', 'k', 'a', 'r']

# %%
names.remove('sham')

# %%
names
# Out:
# ['Om', 'Ganesh', 'priya', 'payal', 'Vaibhav', 'o', 'n', 'k', 'a', 'r']

# %%
names.remove('a')

# %%
names
# Out:
# ['Om', 'Ganesh', 'priya', 'payal', 'Vaibhav', 'o', 'n', 'k', 'r']

# %%
l
# Out:
# [1,
#  2,
#  3,
#  2,
#  1,
#  3,
#  10,
#  'Hello',
#  [10, 20, 30],
#  10,
#  20,
#  30,
#  'h',
#  'e',
#  'l',
#  'l',
#  'o']

# %%
l.pop()
# Out:
# 'o'

# %%
l
# Out:
# [1, 2, 3, 2, 1, 3, 10, 'Hello', [10, 20, 30], 10, 20, 30, 'h', 'e', 'l', 'l']

# %%
l.pop()
# Out:
# 'l'

# %%
l2
# Out:
# [1, 1, 1, 1, 2, 2, 2, 2, 3, 4, 5, 6, 7, 8]

# %%
l2.index(8)
# Out:
# 13

# %%
l2.index(1)
# Out:
# 0

# %%
l2.index(2)
# Out:
# 4

# %%
l2.count(1)
# Out:
# 4

# %%
l2.count(2)
# Out:
# 4

# %%
l2.count(8)
# Out:
# 1

# %%
l2
# Out:
# [1, 1, 1, 1, 2, 2, 2, 2, 3, 4, 5, 6, 7, 8]

# %%
l2.reverse()

# %%
l2
# Out:
# [8, 7, 6, 5, 4, 3, 2, 2, 2, 2, 1, 1, 1, 1]

# %%
l
# Out:
# [1, 2, 3, 2, 1, 3, 10, 'Hello', [10, 20, 30], 10, 20, 30, 'h', 'e', 'l']

# %%
l[::-1]
# Out:
# ['l', 'e', 'h', 30, 20, 10, [10, 20, 30], 'Hello', 10, 3, 1, 2, 3, 2, 1]

# %%
l.sort()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 l.sort()
#
# TypeError: '<' not supported between instances of 'str' and 'int'

# %%
l2
# Out:
# [8, 7, 6, 5, 4, 3, 2, 2, 2, 2, 1, 1, 1, 1]

# %%
l2.sort()

# %%
l2
# Out:
# [1, 1, 1, 1, 2, 2, 2, 2, 3, 4, 5, 6, 7, 8]

# %%
names
# Out:
# ['Om', 'Ganesh', 'priya', 'payal', 'Vaibhav', 'o', 'n', 'k', 'r']

# %%
copy_names = names

# %%
copy_names
# Out:
# ['Om', 'Ganesh', 'priya', 'payal', 'Vaibhav', 'o', 'n', 'k', 'r']

# %%
names.remove('payal')

# %%
names
# Out:
# ['Om', 'Ganesh', 'priya', 'Vaibhav', 'o', 'n', 'k', 'r']

# %%
copy_names
# Out:
# ['Om', 'Ganesh', 'priya', 'Vaibhav', 'o', 'n', 'k', 'r']

# %%
backup_names = names.copy()

# %%
backup_names
# Out:
# ['Om', 'Ganesh', 'priya', 'Vaibhav', 'o', 'n', 'k', 'r']

# %%
names.remove('Ganesh')

# %%
names
# Out:
# ['Om', 'priya', 'Vaibhav', 'o', 'n', 'k', 'r']

# %%
backup_names
# Out:
# ['Om', 'Ganesh', 'priya', 'Vaibhav', 'o', 'n', 'k', 'r']

# %% [markdown]
# # Tuple

# %%
t = (1,1,1,2,3,2,2,4)

# %%
t
# Out:
# (1, 1, 1, 2, 3, 2, 2, 4)

# %%
type(t)
# Out:
# tuple

# %%
t[3]
# Out:
# 2

# %%
t[1:4]
# Out:
# (1, 1, 2)

# %%
t[1] = 100
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[68], line 1
# ----> 1 t[1] = 100
#
# TypeError: 'tuple' object does not support item assignment

# %%
t.count(1)
# Out:
# 3

# %%
t.count(3)
# Out:
# 1

# %%
t.index(4)
# Out:
# 7

# %%
# tuple ----> list convert --> change ----> tuple

# %%
t
# Out:
# (1, 1, 1, 2, 3, 2, 2, 4)

# %%
t = list(t)

# %%
t
# Out:
# [1, 1, 1, 2, 3, 2, 2, 4]

# %%
t[1] = 100

# %%
t
# Out:
# [1, 100, 1, 2, 3, 2, 2, 4]

# %%
t = tuple(t)

# %%
t
# Out:
# (1, 100, 1, 2, 3, 2, 2, 4)

# %% [markdown]
# # Set

# %%
s = {10,1,1,2,5,2,3,3,3,4,5,6,7}

# %%
s
# Out:
# {1, 2, 3, 4, 5, 6, 7, 10}

# %%
names
# Out:
# ['Om', 'priya', 'Vaibhav', 'o', 'n', 'k', 'r']

# %%
set(names)
# Out:
# {'Om', 'Vaibhav', 'k', 'n', 'o', 'priya', 'r'}

# %%
{'c','b','a'}
# Out:
# {'a', 'b', 'c'}

# %%
# Names

# %%
name = 'vaibhav'

# %%
set(name)
# Out:
# {'a', 'b', 'h', 'i', 'v'}

# %%
{'vaibhav'}
# Out:
# {'vaibhav'}

# %%
set('madam')
# Out:
# {'a', 'd', 'm'}

# %%
s1 = {1,2,3,4,5}
s2 = {4,5,6,7,8}

# %%
s1.union(s2)
# Out:
# {1, 2, 3, 4, 5, 6, 7, 8}

# %%
s1.intersection(s2)
# Out:
# {4, 5}

# %%
s1.difference(s2)
# Out:
# {1, 2, 3}

# %%
s2.difference(s1)
# Out:
# {6, 7, 8}

# %%
# dict

# %%
d = {'name':'Vaibhav', 'Mobile':48937638, 'Roll': 30}

# %%
d
# Out:
# {'name': 'Vaibhav', 'Mobile': 48937638, 'Roll': 30}

# %%
d.keys()
# Out:
# dict_keys(['name', 'Mobile', 'Roll'])

# %%
d.values()
# Out:
# dict_values(['Vaibhav', 48937638, 30])

# %%
d['name']
# Out:
# 'Vaibhav'

# %%
d['Roll']
# Out:
# 30

# %%
d['Mobile']
# Out:
# 48937638

# %%
d
# Out:
# {'name': 'Vaibhav', 'Mobile': 48937638, 'Roll': 30}

# %%
d['marks'] = 60

# %%
d
# Out:
# {'name': 'Vaibhav', 'Mobile': 48937638, 'Roll': 30, 'marks': 60}

# %%
d['name'] = 'om'

# %%
d
# Out:
# {'name': 'om', 'Mobile': 48937638, 'Roll': 30, 'marks': 60}
