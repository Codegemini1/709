# %% [markdown]
# # Data Types

# %% [raw]
# Int :- Integer Complete Num
# Numerical Data Type
# Eg:- How many family members ?
# ----> 5,2,4
# Eg:- How many cars you have ?
# ----> 1,2,4

# %%
5
# Out:
# 5

# %%
type(5)
# Out:
# int

# %% [raw]
# Float :- Values in decimal format
# Eg :- Height
# ----->  6.3,4.8, 5.5
# Eg:- Weight
# -----> 80.300, 46.200

# %%
5.5
# Out:
# 5.5

# %%
type(5.5)
# Out:
# float

# %% [raw]
# Complex Num:  Values in Vector
# 10 + 5j
# 8 + 1j

# %%
10 + 5j
# Out:
# (10+5j)

# %% [raw]
# String:- Word, Sentence, Letter
# one line :- ' '    " "
# 'Hello'      , "Python"
# " Today is my friend's birthday"
#
# Multiple line:- ''' ''' , """   """
# """ Today we have srated Python.
# Now we are learning data types in python.
# We have leanred 4 data types till now. """

# %%
'Hello'
# Out:
# 'Hello'

# %%
"Python"
# Out:
# 'Python'

# %%
""" Today we have srated Python.
Now we are learning data types in python.
We have leanred 4 data types till now. """
# Out:
# ' Today we have srated Python.\nNow we are learning data types in python.\nWe have leanred 4 data types till now. '

# %%
print("""Today we have srated Python.
Now we are learning data types in python.
We have leanred 4 data types till now. """)
# Out:
# Today we have srated Python.
# Now we are learning data types in python.
# We have leanred 4 data types till now.

# %%
type('Hello')
# Out:
# str

# %% [raw]
# Boolean :- True False
# 5 > 2
# ---> True

# %%
5 > 2
# Out:
# True

# %%
type(True)
# Out:
# bool

# %%
type(False)
# Out:
# bool
