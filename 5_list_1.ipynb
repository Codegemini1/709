# %% [markdown]
# # List

# %%
num = [1,4,6,2,1]

# %%
num
# Out:
# [1, 4, 6, 2, 1]

# %%
type(num)
# Out:
# list

# %%
names = ['Om', 'priya', 'payal', 'sham']

# %%
names
# Out:
# ['Om', 'priya', 'payal', 'sham']

# %%
mix = [1,1.5,True,'Hello',10+5j]

# %%
mix
# Out:
# [1, 1.5, True, 'Hello', (10+5j)]

# %%
num
# Out:
# [1, 4, 6, 2, 1]

# %% [markdown]
# # Indexing|

# %%
num[2]
# Out:
# 6

# %%
num[0]
# Out:
# 1

# %%
num[1]
# Out:
# 4

# %%
num[2]
# Out:
# 6

# %%
num[3]
# Out:
# 2

# %%
num[4]
# Out:
# 1

# %%
num[5]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 num[5]
#
# IndexError: list index out of range

# %%
names
# Out:
# ['Om', 'priya', 'payal', 'sham']

# %%
names[2]
# Out:
# 'payal'

# %%
names[-1]
# Out:
# 'sham'

# %%
names[-2]
# Out:
# 'payal'

# %%
num
# Out:
# [1, 4, 6, 2, 1]

# %% [markdown]
# # Slicing Operation

# %%
num[0:3]
# Out:
# [1, 4, 6]

# %%
num[1:4]
# Out:
# [4, 6, 2]

# %%
names
# Out:
# ['Om', 'priya', 'payal', 'sham']

# %%
names[0:3]
# Out:
# ['Om', 'priya', 'payal']

# %%
names[1:4]
# Out:
# ['priya', 'payal', 'sham']

# %%
data = [10,20,30,40,50,60,70,80]

# %%
data
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
data
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
data[:]
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
data[2:]
# Out:
# [30, 40, 50, 60, 70, 80]

# %%
data[:5]
# Out:
# [10, 20, 30, 40, 50]

# %%
data
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
data[0:8]
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
data[0:8:1]
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
data
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
data[::2]
# Out:
# [10, 30, 50, 70]

# %%
data[1::2]
# Out:
# [20, 40, 60, 80]

# %%
data
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
data[::-1]
# Out:
# [80, 70, 60, 50, 40, 30, 20, 10]

# %%
data[5::-1]
# Out:
# [60, 50, 40, 30, 20, 10]

# %%
data
# Out:
# [10, 20, 30, 40, 50, 60, 70, 80]

# %%
data[5:2:-1]
# Out:
# [60, 50, 40]

# %%
data[5:2:1]
# Out:
# []

# %% [raw]
# Q:- jdhdxvgzxhbaxj

# %%
num
# Out:
# [1, 4, 6, 2, 1]

# %%
num[1]
# Out:
# 4

# %%
num[1] = 400

# %%
num
# Out:
# [1, 400, 6, 2, 1]

# %%
# Nested List

# %%
l = [1,2,3,[10,20,30], 4]

# %%
l
# Out:
# [1, 2, 3, [10, 20, 30], 4]

# %%
l[0]
# Out:
# 1

# %%
l[1]
# Out:
# 2

# %%
l[2]
# Out:
# 3

# %%
l[3]
# Out:
# [10, 20, 30]

# %%
l
# Out:
# [1, 2, 3, [10, 20, 30], 4]

# %%
l[4]
# Out:
# 4

# %%
l[3]
# Out:
# [10, 20, 30]

# %%
l[3][1]
# Out:
# 20

# %%
l2  = [10,20,[1,2,3,[100,200,300], 4,5],30,40]

# %%
l2
# Out:
# [10, 20, [1, 2, 3, [100, 200, 300], 4, 5], 30, 40]

# %%
l2[2]
# Out:
# [1, 2, 3, [100, 200, 300], 4, 5]

# %%
l2[2][3][2]
# Out:
# 300

# %% [raw]
# 1. Deep Indexing Practice Given the list: data = ["a", "b", ["c", ["d", "e", "target"], "f"], "g"]

# %%
data = ["a", "b", ["c", ["d", "e", "target"], "f"], "g"]

# %%
data[0]
# Out:
# 'a'

# %%
data[1]
# Out:
# 'b'

# %%
data[2]
# Out:
# ['c', ['d', 'e', 'target'], 'f']

# %%
data[2][1]
# Out:
# ['d', 'e', 'target']

# %%
data[2][1][2]
# Out:
# 'target'
