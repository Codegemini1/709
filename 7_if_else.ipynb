# %%
time = 11

# %%
if time > 9:          # true
    print('No entry')
else:
    print('Door is open')
# Out:
# No entry

# %%
time > 9
# Out:
# True

# %%
marks = 10
if marks > 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Fail

# %%
password = input('Enter your password')

if password == 'hello':
    print('Right')
else:
    print('Wrong password')
# Out:
# Enter your password hello
# Right

# %%
'python' == 'hello'
# Out:
# False

# %%
'hello' == 'hello'
# Out:
# True

# %%
marks = int(input('Enter your marks'))

if marks > 90:
    print('A+')
elif marks > 70:
    print('B')
elif marks > 50:
    print('C')
elif marks >= 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Enter your marks 98
# A+

# %%
course = input('Enter your course name')

if course == 'python':
    print('Yes we provide python course')
elif course == 'java':
    print('Yes we provide java course')
elif course == 'uiux':
    print('Yes we provide uiux course')
else:
    print(f'No, we dont provide {course} course')
# Out:
# Enter your course name aws
# No, we dont provide aws course

# %%
marks = int(input('Enter your marks'))

if marks > 90:
    print('A+')
elif marks > 70:
    print('B')
elif marks > 50:
    print('C')
elif marks >= 35:
    print('Pass')
else:
    print('Fail')
# Out:
# Enter your marks 150
# A+

# %%
marks = int(input('ENter your marks'))
if marks > 90 and marks <= 100:
    print('A+')
elif marks > 70 and marks <= 90:
    print('B')
elif marks > 50 and marks <= 70:
    print('C')
elif marks >= 35 and marks <= 50:
    print('Pass')
elif marks >= 0 and marks < 35:
    print('Fail')
else:
    print('Please write marks between range of 0 - 100')
# Out:
# ENter your marks 15
# Fail

# %%
120 > 90 and 120 <= 100

# %%
120 > 90
# Out:
# True

# %%
120 <= 100
# Out:
# False
