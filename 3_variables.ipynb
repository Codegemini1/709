# %%
a = 5

# %%
a
# Out:
# 5

# %%
5 = 10
# Out:
#   Cell In[3], line 1
#     5 = 10
#     ^
# SyntaxError: cannot assign to literal here. Maybe you meant '==' instead of '='?

# %%
a5 = 10

# %%
a5
# Out:
# 10

# %%
a_5 = 20

# %%
a_5
# Out:
# 20

# %%
@ = 50
# Out:
#   Cell In[8], line 1
#     @ = 50
#       ^
# SyntaxError: invalid syntax

# %%
$ = 'Hello'
# Out:
#   Cell In[9], line 1
#     $ = 'Hello'
#     ^
# SyntaxError: invalid syntax

# %%
type(5)
# Out:
# int

# %%
type = 50

# %%
type
# Out:
# 50

# %%
type(5)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 type(5)
#
# TypeError: 'int' object is not callable

# %%
type(5)
# Out:
# int

# %%
len('Hello')
# Out:
# 5

# %%
len = 50

# %%
len
# Out:
# 50

# %%
a = 5

# %%
b = 10

# %%
c = a + b  #5 + 10

# %%
c
# Out:
# 15

# %%
x,y,z = 10,20,30

# %%
x
# Out:
# 10

# %%
y
# Out:
# 20

# %%
z
# Out:
# 30

# %%
o = 1,2,3,4,5,6

# %%
o
# Out:
# (1, 2, 3, 4, 5, 6)

# %%
name = 'Vaibhav'
last_name = 'Bhosale'

# %%
name + last_name
# Out:
# 'VaibhavBhosale'

# %%
name + 10
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 name + 10
#
# TypeError: can only concatenate str (not "int") to str

# %%
name + ' ' + last_name
# Out:
# 'Vaibhav Bhosale'

# %%
'My name is' + name
# Out:
# 'My name isVaibhav'

# %%
'My name is ' + name
# Out:
# 'My name is Vaibhav'

# %%
'My first  name is' + name + 'last name is' + last_name
# Out:
# 'My first  name isVaibhavlast name isBhosale'

# %%
a
# Out:
# 5

# %%
a + 5
# Out:
# 10

# %%
a
# Out:
# 5

# %%
a = a + 5

# %%
a
# Out:
# 10

# %%
b = 10

# %%
b = b - 5

# %%
b
# Out:
# 5

# %%
c = 20

# %%
c += 5  # c = c + 5

# %%
c
# Out:
# 25

# %%
# type casting

# %%
num = 10

# %%
type(10)
# Out:
# int

# %%
num2 = '10'

# %%
type(num2)
# Out:
# str

# %%
int(num2)
# Out:
# 10

# %%
num2 = int(num2)

# %%
type(num2)
# Out:
# int

# %%
int('123')
# Out:
# 123

# %%
float(10)
# Out:
# 10.0

# %%
int('hello')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[45], line 1
# ----> 1 int('hello')
#
# ValueError: invalid literal for int() with base 10: 'hello'

# %%
str(121)
# Out:
# '121'

# %%
# Operations

# %%
name
# Out:
# 'Vaibhav'

# %%
print('My name is ' + name)
# Out:
# My name is Vaibhav

# %%
print('My age is' + 20)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 print('My age is' + 20)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print('My age is', 20)
# Out:
# My age is 20

# %%
age = 25

# %%
print(f'My name is {name} and my age is {age}')
# Out:
# My name is Vaibhav and my age is 25

# %%
name = 'Om'

# %%
print(f'My name is {name} and my age is {age}')
# Out:
# My name is Om and my age is 25
